# %%
# !pip install pyitlib

# %%
import numpy as np
from pyitlib import discrete_random_variable as drv
import pandas as pd

# %%
df = pd.read_csv(r'/content/Val_prediction_matrix.csv')
print (df)

# %%
predict = df[['VGG16', 'VGG19', 'Xception', 'Inception' , 'InceptionResnetV2']]
print(predict)
y_data = df['True Label']
print(y_data)

# %%
pred_mat = predict.values.tolist()
Y = y_data.values.tolist()

# %%
#Weight Calculation
sum = 0
w=[]
for i in range(5):
  w.append([0,0,0,0,0])
print(w)
val = [.97, .98, .99, .99, .99]
for i in range(5):
  for j in range(5):
    if (i == j):
      w[i][j] = 0
    if (i != j):
      sum = 0
      for k in range(5):
        if  (k!=i and k!=j):
          sum = sum + val[k]
          print(val[k])
      avg = sum/3
      print(val)
      print(avg)
      print(i)
      print(j)
      w[i][j] = avg
      print("@@@@@@@@@@@@@@@@@@")

# %%
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(1, len(s)+1))

# %%
shapley_value_list = []
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  M = []
  for j in range(len(N)):
    if(i != N[j]):
      M.append(N[j])
  print(M)
  classifier_list =list(powerset(M))
  for k in range(len(classifier_list)):
    '''print(len(classifier_list[k]))'''
    st = str(classifier_list[k])
    classifier_subset = []
    for l in range(len(st)):
      if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
        classifier_subset.append(int(st[l]))
    '''print(classifier_subset)'''
    total = 0
    if(len(classifier_subset) == 1):
      a_1 = classifier_subset[0]
      X_1 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif = drv.information_mutual(X_i, X_1)
      marginal_info = m_info_class - w[i-1][a_1-1]*m_info_classif
      total = total + (marginal_info*6/120)
    if(len(classifier_subset) == 2):
      a_1 = classifier_subset[0]
      a_2 = classifier_subset[1]
      X_1 = []
      X_2 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      for asdf in range(len(pred_mat)):
        X_2.append(pred_mat[asdf][a_2-1])
      X_2 = np.asarray(X_2)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif_1 = drv.information_mutual(X_i, X_1)
      m_info_classif_2 = drv.information_mutual(X_i, X_2)
      m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2)/2
      marginal_info_2 = m_info_class - m_info_classif
      total = total + (marginal_info_2*4/120)
    if(len(classifier_subset) == 3):
      a_1 = classifier_subset[0]
      a_2 = classifier_subset[1]
      a_3 = classifier_subset[2]
      X_1 = []
      X_2 = []
      X_3 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      for asdf in range(len(pred_mat)):
        X_2.append(pred_mat[asdf][a_2-1])
      X_2 = np.asarray(X_2)
      for asdf in range(len(pred_mat)):
        X_3.append(pred_mat[asdf][a_3-1])
      X_3 = np.asarray(X_3)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif_1 = drv.information_mutual(X_i, X_1)
      m_info_classif_2 = drv.information_mutual(X_i, X_2)
      m_info_classif_3 = drv.information_mutual(X_i, X_3)
      m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][a_3-1]*m_info_classif_3)/3
      marginal_info_3 = m_info_class - m_info_classif
      total = total + (marginal_info_3*6/120)
    if(len(classifier_subset) == 4):
      a_1 = classifier_subset[0]
      a_2 = classifier_subset[1]
      a_3 = classifier_subset[2]
      a_4 = classifier_subset[3]
      X_1 = []
      X_2 = []
      X_3 = []
      X_4 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      for asdf in range(len(pred_mat)):
        X_2.append(pred_mat[asdf][a_2-1])
      X_2 = np.asarray(X_2)
      for asdf in range(len(pred_mat)):
        X_3.append(pred_mat[asdf][a_3-1])
      X_3 = np.asarray(X_3)
      for asdf in range(len(pred_mat)):
        X_4.append(pred_mat[asdf][a_4-1])
      X_4 = np.asarray(X_4)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif_1 = drv.information_mutual(X_i, X_1)
      m_info_classif_2 = drv.information_mutual(X_i, X_2)
      m_info_classif_3 = drv.information_mutual(X_i, X_3)
      m_info_classif_4 = drv.information_mutual(X_i, X_4)
      m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][a_3-1]*m_info_classif_3 + w[i-1][a_4-1]*m_info_classif_4)/4
      marginal_info_4 =  m_info_class - m_info_classif
      total = total + marginal_info_4*24/120
  shapley_value = total 
  shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  for d in range(1,6,1):
    if(d == i):
      break
    X_d = []
    for asdf in range(len(pred_mat)):
      X_d.append(pred_mat[asdf][d-1])
    X_d = np.asarray(X_d)
    M = []
    for j in range(len(N)):
      if(i != N[j] and d != N[j]):
        M.append(N[j])
    print(M)
    classifier_list =list(powerset(M))
    for k in range(len(classifier_list)):
      '''print(len(classifier_list[k]))'''
      st = str(classifier_list[k])
      classifier_subset = []
      for l in range(len(st)):
        if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
          classifier_subset.append(int(st[l]))
      print(classifier_subset)
      total = 0
      if(len(classifier_subset) == 1):
        a_1 = classifier_subset[0]
        X_1 = []
        for asdf in range(len(pred_mat)):
          X_1.append(pred_mat[asdf][a_1-1])
        X_1 = np.asarray(X_1)
        m_info_class_1 = drv.information_mutual(X_i, Y)
        m_info_class_2 = drv.information_mutual(X_d, Y)
        m_info_classif_1 = drv.information_mutual(X_i, X_1)
        m_info_classif_2 = drv.information_mutual(X_i, X_d)
        m_info_classif_3 = drv.information_mutual(X_d, X_1)
        m_info_class = (m_info_class_1 + m_info_class_2)/2
        m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][d-1]*m_info_classif_2 + w[d-1][a_1-1]*m_info_classif_3)/3
        marginal_info_1 = m_info_class - m_info_classif
        total = total + (marginal_info_1*6/120)
      if(len(classifier_subset) == 2):
        a_1 = classifier_subset[0]
        a_2 = classifier_subset[1]
        X_1 = []
        X_2 = []
        for asdf in range(len(pred_mat)):
          X_1.append(pred_mat[asdf][a_1-1])
        X_1 = np.asarray(X_1)
        for asdf in range(len(pred_mat)):
          X_2.append(pred_mat[asdf][a_2-1])
        X_2 = np.asarray(X_2)
        m_info_class_1 = drv.information_mutual(X_i, Y)
        m_info_class_2 = drv.information_mutual(X_d, Y)
        m_info_classif_1 = drv.information_mutual(X_i, X_1)
        m_info_classif_2 = drv.information_mutual(X_i, X_2)
        m_info_classif_3 = drv.information_mutual(X_i, X_d)
        m_info_classif_4 = drv.information_mutual(X_d, X_2)
        m_info_classif_5 = drv.information_mutual(X_d, X_2)
        m_info_class = (m_info_class_1 + m_info_class_2)/2
        m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][d-1]*m_info_classif_3 + w[d-1][a_2-1]*m_info_classif_4 + w[d-1][a_2-1]*m_info_classif_5)/5
        marginal_info_2 = m_info_class - m_info_classif
        total = total + (marginal_info_2*4/120)
      if(len(classifier_subset) == 3):
        a_1 = classifier_subset[0]
        a_2 = classifier_subset[1]
        a_3 = classifier_subset[2]
        X_1 = []
        X_2 = []
        X_3 = []
        for asdf in range(len(pred_mat)):
          X_1.append(pred_mat[asdf][a_1-1])
        X_1 = np.asarray(X_1)
        for asdf in range(len(pred_mat)):
          X_2.append(pred_mat[asdf][a_2-1])
        X_2 = np.asarray(X_2)
        for asdf in range(len(pred_mat)):
          X_3.append(pred_mat[asdf][a_3-1])
        X_3 = np.asarray(X_3)
        m_info_class_1 = drv.information_mutual(X_i, Y)
        m_info_class_2 = drv.information_mutual(X_d, Y)
        m_info_classif_1 = drv.information_mutual(X_i, X_1)
        m_info_classif_2 = drv.information_mutual(X_i, X_2)
        m_info_classif_3 = drv.information_mutual(X_i, X_3)
        m_info_classif_4 = drv.information_mutual(X_d, X_1)
        m_info_classif_5 = drv.information_mutual(X_d, X_2)
        m_info_classif_6 = drv.information_mutual(X_d, X_3)
        m_info_classif_7 = drv.information_mutual(X_i, X_d)
        m_info_class = (m_info_class_1 + m_info_class_2)/2
        m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][a_3-1]*m_info_classif_3 + w[d-1][a_1-1]*m_info_classif_4 + w[d-1][a_2-1]*m_info_classif_5 + w[d-1][a_3-1]*m_info_classif_6 + w[i-1][d-1]*m_info_classif_7)/7
        marginal_info_3 = m_info_class - m_info_classif
        total = total + (marginal_info_3*6/120)
    shapley_value = total 
    shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  for d in range(1,6,1):
    if(d == i):
      break
    X_d = []
    for asdf in range(len(pred_mat)):
      X_d.append(pred_mat[asdf][d-1])
    X_d = np.asarray(X_d)
    for f in range(1,6,1):
      if( f == d or f==i):
        break
      X_f = []
      for asdf in range(len(pred_mat)):
        X_f.append(pred_mat[asdf][f-1])
      X_f = np.asarray(X_f)
      M = []
      for j in range(len(N)):
        if(i != N[j] and d != N[j] and f != N[j]):
          M.append(N[j])
      print(M)
      classifier_list =list(powerset(M))
      for k in range(len(classifier_list)):
        '''print(len(classifier_list[k]))'''
        st = str(classifier_list[k])
        classifier_subset = []
        for l in range(len(st)):
          if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
            classifier_subset.append(int(st[l]))
        print(classifier_subset)
        total = 0
        if(len(classifier_subset) == 1):
          a_1 = classifier_subset[0]
          X_1 = []
          for asdf in range(len(pred_mat)):
            X_1.append(pred_mat[asdf][a_1-1])
          X_1 = np.asarray(X_1)
          m_info_class_1 = drv.information_mutual(X_i, Y)
          m_info_class_2 = drv.information_mutual(X_d, Y)
          m_info_class_3 = drv.information_mutual(X_f, Y)
          m_info_classif_1 = drv.information_mutual(X_i, X_1)
          m_info_classif_2 = drv.information_mutual(X_i, X_d)
          m_info_classif_3 = drv.information_mutual(X_i, X_f)
          m_info_classif_4 = drv.information_mutual(X_d, X_f)
          m_info_classif_5 = drv.information_mutual(X_d, X_1)
          m_info_classif_6 = drv.information_mutual(X_f, X_1)
          m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3)/3
          m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][d-1]*m_info_classif_2 + w[i-1][f-1]*m_info_classif_3 + w[d-1][f-1]*m_info_classif_4 + w[d-1][a_1-1]*m_info_classif_5 + w[f-1][a_1-1]*m_info_classif_6)/6
          marginal_info_1 = m_info_class - m_info_classif
          total = total + (marginal_info_1*6/120)
        if(len(classifier_subset) == 2):
          a_1 = classifier_subset[0]
          a_2 = classifier_subset[1]
          X_1 = []
          X_2 = []
          for asdf in range(len(pred_mat)):
            X_1.append(pred_mat[asdf][a_1-1])
          X_1 = np.asarray(X_1)
          for asdf in range(len(pred_mat)):
            X_2.append(pred_mat[asdf][a_2-1])
          X_2 = np.asarray(X_2)
          m_info_class_1 = drv.information_mutual(X_i, Y)
          m_info_class_2 = drv.information_mutual(X_d, Y)
          m_info_class_3 = drv.information_mutual(X_f, Y)
          m_info_classif_1 = drv.information_mutual(X_i, X_1)
          m_info_classif_2 = drv.information_mutual(X_i, X_2)
          m_info_classif_3 = drv.information_mutual(X_d, X_1)
          m_info_classif_4 = drv.information_mutual(X_d, X_2)
          m_info_classif_5 = drv.information_mutual(X_f, X_1)
          m_info_classif_6 = drv.information_mutual(X_f, X_2)
          m_info_classif_7 = drv.information_mutual(X_i, X_d)
          m_info_classif_8 = drv.information_mutual(X_i, X_f)
          m_info_classif_9 = drv.information_mutual(X_d, X_f)
          m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3)/3
          m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[d-1][a_1-1]*m_info_classif_3 + w[d-1][a_2-1]*m_info_classif_4 + w[f-1][a_2-1]*m_info_classif_5 + w[f-1][a_3-1]*m_info_classif_6 + w[i-1][d-1]*m_info_classif_7 + w[i-1][f-1]*m_info_classif_8 + w[d-1][f-1]*m_info_classif_9)/9
          marginal_info_2 = m_info_class - m_info_classif
          total = total + (marginal_info_2*4/120)
      shapley_value = total 
      shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  for d in range(1,6,1):
    if(d == i):
      break
    X_d = []
    for asdf in range(len(pred_mat)):
      X_d.append(pred_mat[asdf][d-1])
    X_d = np.asarray(X_d)
    for f in range(1,6,1):
      if( f == d or f==i):
        break
      X_f = []
      for asdf in range(len(pred_mat)):
        X_f.append(pred_mat[asdf][f-1])
      X_f = np.asarray(X_f)
      for r in range(1,6,1):
        if( r == d or r==i or r == f):
          break
        X_r = []
        for asdf in range(len(pred_mat)):
          X_r.append(pred_mat[asdf][r-1])
        X_r = np.asarray(X_r)
        M = []
        for j in range(len(N)):
          if(i != N[j] and d != N[j] and f != N[j] and r != N[j]):
            M.append(N[j])
        print(M)
        classifier_list =list(powerset(M))
        for k in range(len(classifier_list)):
          '''print(len(classifier_list[k]))'''
          st = str(classifier_list[k])
          classifier_subset = []
          for l in range(len(st)):
            if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
              classifier_subset.append(int(st[l]))
          print(classifier_subset)
          total = 0
          if(len(classifier_subset) == 1):
            a_1 = classifier_subset[0]
            X_1 = []
            for asdf in range(len(pred_mat)):
              X_1.append(pred_mat[asdf][a_1-1])
            X_1 = np.asarray(X_1)
            m_info_class_1 = drv.information_mutual(X_i, Y)
            m_info_class_2 = drv.information_mutual(X_d, Y)
            m_info_class_3 = drv.information_mutual(X_f, Y)
            m_info_class_4 = drv.information_mutual(X_r, Y)
            m_info_classif_1 = drv.information_mutual(X_i, X_1)
            m_info_classif_2 = drv.information_mutual(X_i, X_d)
            m_info_classif_3 = drv.information_mutual(X_i, X_r)
            m_info_classif_4 = drv.information_mutual(X_r, X_d)
            m_info_classif_5 = drv.information_mutual(X_r, X_f)
            m_info_classif_6 = drv.information_mutual(X_i, X_f)
            m_info_classif_7 = drv.information_mutual(X_d, X_f)
            m_info_classif_8 = drv.information_mutual(X_d, X_1)
            m_info_classif_9 = drv.information_mutual(X_f, X_1)
            m_info_classif_10 = drv.information_mutual(X_r, X_1)
            m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3 + m_info_class_4)/4
            m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][d-1]*m_info_classif_2 + w[i-1][r-1]*m_info_classif_3 + w[r-1][d-1]*m_info_classif_4 + w[r-1][f-1]*m_info_classif_5 + w[i-1][f-1]*m_info_classif_6 + w[d-1][f-1]*m_info_classif_7 + w[d-1][a_1-1]*m_info_classif_8 + w[f-1][a_1-1]*m_info_classif_9 + w[r-1][a_1-1]*m_info_classif_10)/10
            marginal_info_1 = m_info_class - m_info_classif
            total = total + (marginal_info_1*6/120)
        shapley_value = total 
        shapley_value_list.append(shapley_value)

# %%
X_i = []
X_d = []
X_f = []
X_r = []
X_p = []
for asdf in range(len(pred_mat)):
  X_i.append(pred_mat[asdf][0])
X_i = np.asarray(X_i)
for asdf in range(len(pred_mat)):
  X_d.append(pred_mat[asdf][1])
X_d = np.asarray(X_d)
for asdf in range(len(pred_mat)):
  X_f.append(pred_mat[asdf][2])
X_f = np.asarray(X_f)
for asdf in range(len(pred_mat)):
  X_r.append(pred_mat[asdf][3])
X_r = np.asarray(X_r)
for asdf in range(len(pred_mat)):
  X_p.append(pred_mat[asdf][4])
X_p = np.asarray(X_p)
m_info_class_1 = drv.information_mutual(X_i, Y)
m_info_class_2 = drv.information_mutual(X_d, Y)
m_info_class_3 = drv.information_mutual(X_f, Y)
m_info_class_4 = drv.information_mutual(X_r, Y)
m_info_class_5 = drv.information_mutual(X_p, Y)
m_info_classif_1 = drv.information_mutual(X_i, X_d)
m_info_classif_2 = drv.information_mutual(X_i, X_f)
m_info_classif_3 = drv.information_mutual(X_i, X_r)
m_info_classif_4 = drv.information_mutual(X_i, X_p)
m_info_classif_5 = drv.information_mutual(X_d, X_f)
m_info_classif_6 = drv.information_mutual(X_d, X_r)
m_info_classif_7 = drv.information_mutual(X_d, X_p)
m_info_classif_8 = drv.information_mutual(X_f, X_r)
m_info_classif_9 = drv.information_mutual(X_f, X_p)
m_info_classif_10 = drv.information_mutual(X_r, X_p)
m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3 + m_info_class_4 + m_info_class_5)/5
m_info_classif = (w[0][1]*m_info_classif_1 + w[0][2]*m_info_classif_2 + w[0][3]*m_info_classif_3 + w[0][4]*m_info_classif_4 + w[1][2]*m_info_classif_5 + w[1][3]*m_info_classif_6 + w[1][4]*m_info_classif_7 + w[2][3]*m_info_classif_8 + w[2][4]*m_info_classif_9 + w[3][4]*m_info_classif_10)/10
marginal_info_1 = m_info_class - m_info_classif
total = total + (marginal_info_1*6/120)
shapley_value = total 
shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
Subset_list = []
total = 0
for i in range(1, 6, 1):
  K =[]
  K.append(i)
  Subset_list.append(K)
print(Subset_list)
for i in range(1, 6, 1):
  for d in range(1,6,1):
    K = []
    if(d == i):
      break
    K.append(d)
    K.append(i)
    Subset_list.append(K)
print(Subset_list)
for i in range(1, 6, 1):
  for d in range(1,6,1):
    if(d == i):
      break
    for f in range(1,6,1):
      K = []
      if( f == d or f==i):
        break
      K.append(f)
      K.append(d)
      K.append(i)
      Subset_list.append(K)
print(Subset_list)
for i in range(1, 6, 1):
  for d in range(1,6,1):
    if(d == i):
      break
    for f in range(1,6,1):
      if( f == d or f==i):
        break
      for r in range(1,6,1):
        K = []
        if( r == d or r==i or r == f):
          break
        K.append(r)
        K.append(f)
        K.append(d)
        K.append(i)
        Subset_list.append(K)
print(Subset_list)
K = []
K.append(1)
K.append(2)
K.append(3)
K.append(4)
K.append(5)
Subset_list.append(K)
print(Subset_list)

# %%
list_mu = []
list_mu.append(shapley_value_list[0])
list_mu.append(shapley_value_list[1])
list_mu.append(shapley_value_list[2])
list_mu.append(shapley_value_list[3])
list_mu.append(shapley_value_list[4])
for i in range(5, len(Subset_list)):
  K = Subset_list[i]
  if (len(K) == 2):
    shap_of_2 = shapley_value_list[i]
    m1 = K[0]
    m2 = K[1]
    temp1 = shapley_value_list[m1-1]
    temp2 = shapley_value_list[m2-1]
    if (temp1>temp2):
      mu_m2 = temp1
      mu_m1 = temp2
    else:
      mu_m2 = temp2
      mu_m1 = temp1
    mu_additive = mu_m1 + mu_m2
    if (mu_m2 == mu_m1):
      print(K)
      if (shap_of_2 < mu_m2 and shap_of_2 > 0):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2)
        mu_of_2 = (r1*mu_additive + r2*mu_m2)/(r1 + r2)
        print(mu_of_2)
        list_mu.append(mu_of_2)
      if(shap_of_2 >= mu_m2):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2)
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
        print(mu_of_2)
        list_mu.append(mu_of_2)
    if (mu_m2 >= 0 and mu_m1 >= 0 and mu_m2 != mu_m1):
      ratio = (mu_m2 - mu_m1)/mu_m2
      fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
      if (shap_of_2 >= mu_m2):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2 - mu_m1)
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
      if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2 - mu_m1)
        mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
      if (shap_of_2 < mu_m1 and shap_of_2 > 0):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2 - mu_m1)
        mu_of_2 = (r2*fixed_pt - r1*mu_additive)/(r2 - r1)
      if (shap_of_2 <= 0):
        mu_of_2 = mu_m2
      list_mu.append(mu_of_2)
      print(K)
      print(mu_of_2)
  if(len(K) == 3):
    shap_of_2 = shapley_value_list[i]
    maximum = 0
    ARR = []
    for t in range(0,len(K)):
      for g in range(0,len(K)):
        check = []
        if (K[t] > K[g]):
          check.append(K[g])
          check.append(K[t])
          for r in range(5 , 15):
            if (check == Subset_list[r]):
              sh = list_mu[r]
              if (sh> maximum):
                maximum = sh
                ARR = check
                for ss in range(0,3):
                  if (ss!= t and ss != g):
                    left = K[ss]
                    break
    temp = list_mu[left-1]
    if (maximum > temp): 
      mu_m2 = maximum
      mu_m1 = temp
    else:
      mu_m2 = temp
      mu_m1 = maximum
    mu_additive = mu_m1 + mu_m2
    if (mu_m2 >= 0 and mu_m1 >= 0):
      ratio = (mu_m2 - mu_m1)/mu_m2
      fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
      if (shap_of_2 >= mu_m2):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
      if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
      if (shap_of_2 < mu_m1 and shap_of_2 > 0):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r2*fixed_pt - r1*mu_additive )/(r2 - r1)
      if (shap_of_2 <= 0):
        mu_of_2 = mu_m2
      list_mu.append(mu_of_2)
      print(K)
      print(mu_of_2)
  if (len(K) == 4):
      shap_of_2 = shapley_value_list[i]
      maximum = 0
      ARR = []
      for t in range(0,len(K)):
            for g in range(0,len(K)):
              for h in range(0,len(K)):
                check = []
                if (t > g and g > h ):
                  check.append(K[t])
                  check.append(K[g])
                  check.append(K[h])
                  check.sort()
                  print(check)
                  for r in range(15 , 25):
                    if (check == Subset_list[r]):
                      sh = list_mu[r]
                      if (sh> maximum):
                        maximum = sh
                        ARR = check
                        for ss in range(0,3):
                          if (ss!= t and ss != g):
                            left = K[ss]
                            break
      temp = list_mu[left-1]
      if (maximum > temp): 
        mu_m2 = maximum
        mu_m1 = temp
      else:
        mu_m2 = temp
        mu_m1 = maximum
      mu_additive = mu_m1 + mu_m2
      if (mu_m2 >= 0 and mu_m1 >= 0):
        ratio = (mu_m2 - mu_m1)/mu_m2
        fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
        if (shap_of_2 >= mu_m2):
          r2 = shap_of_2 - mu_m2
          r1 = shap_of_2 - mu_m1
          mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
        if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
          r2 = shap_of_2 - mu_m2
          r1 = shap_of_2 - mu_m1
          mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
        if (shap_of_2 < mu_m1 and shap_of_2 > 0):
          r2 = shap_of_2 - mu_m2
          r1 = shap_of_2 - mu_m1
          mu_of_2 = (r2*fixed_pt - r1*mu_additive )/(r2 - r1)
        if (shap_of_2 <= 0):
          mu_of_2 = mu_m2
        list_mu.append(mu_of_2)
  if (len(K) == 5):
    shap_of_2 = shapley_value_list[i]
    maximum = 0
    ARR = []
    for t in range(0,len(K)):
      for g in range(0,len(K)):
        for h in range(0,len(K)):
          for ee in range(0, len(K)):
            check = []
            if (t > g and g > h and h > ee ):
              check.append(K[t])
              check.append(K[g])
              check.append(K[h])
              check.append(K[ee])
              check.sort()
              print(check)
              for r in range(25 , 30):
                    if (check == Subset_list[r]):
                      sh = list_mu[r]
                      if (sh> maximum):
                        maximum = sh
                        ARR = check
                        for ss in range(0,3):
                          if (ss!= t and ss != g):
                            left = K[ss]
                            break
    temp = list_mu[left-1]
    if (maximum > temp): 
      mu_m2 = maximum
      mu_m1 = temp
    else:
      mu_m2 = temp
      mu_m1 = maximum
    mu_additive = mu_m1 + mu_m2
    if (mu_m2 >= 0 and mu_m1 >= 0):
      ratio = (mu_m2 - mu_m1)/mu_m2
      fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
      if (shap_of_2 >= mu_m2):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
      if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
      if (shap_of_2 < mu_m1 and shap_of_2 > 0):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r2*fixed_pt - r1*mu_additive )/(r2 - r1)
      if (shap_of_2 <= 0):
        mu_of_2 = mu_m2  
      list_mu.append(mu_of_2)

# %%
for i in range(len(Subset_list)):
  print(Subset_list[i])
  print(list_mu[i])

# %%
measure_max = max(list_mu)
print(measure_max)

# %%
for k in range(len(list_mu)):
  list_mu[k] = list_mu[k]/measure_max

# %%
for k in range(len(list_mu)):
  print(k)
  print(Subset_list[k])
  print(list_mu[k])

# %%
df_1 = pd.read_csv(r'/content/test_confidence_matrix (1).csv')
print (df_1)

# %%
class_0 = df_1[['vgg16_class0', 'vgg19_class0', 'xception_class0', 'inception_class0' , 'incepresnet_class0']]
print(class_0)
class_1 = df_1[['vgg16_class1', 'vgg19_class1', 'xception_class1', 'inception_class1' , 'incepresnet_class1']]
print(class_1)
class_2 = df_1[['vgg16_class2', 'vgg19_class2', 'xception_class2', 'inception_class2' , 'incepresnet_class2']]
print(class_2)
class_3 = df_1[['vgg16_class3', 'vgg19_class3', 'xception_class3', 'inception_class3' , 'incepresnet_class3']]
print(class_3)

# %%
class_0 = class_0.values.tolist()
class_1 = class_1.values.tolist()
class_2 = class_2.values.tolist()
class_3 = class_3.values.tolist()

# %%
print(class_0)
print(len(class_0))
print(class_0[0])

# %%
fa_cl0 = []
for sample in range(len(class_0)):
  print(class_0[sample])
  min_cl0 = min(class_0[sample])
  ar1 = []
  val1 = []
  ar2 = []
  val2 = []
  ar3 = []
  val3 = []
  ar4 = []
  val4 = []
  db = 0
  for i in range(len(class_0[sample])):
    if (class_0[sample][i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db = db + 1
      v1 = class_0[sample][temp]
    else :
      ar1.append(i+1)
      val1.append(class_0[sample][i])
  print(v1)
  print(ar1)
  print(val1)
  for j in range(len(Subset_list)):
    if (ar1 == Subset_list[j]):
      f2 = list_mu[j]
      print(f2)

  min_cl0 = min(val1)
  db = 0
  for i in range(len(val1)):
    if (val1[i] == min_cl0 and db == 0):
      temp = i
      db =  db + 1
      print(temp+1)
      v2 = val1[temp]
    else :
      ar2.append(ar1[i])
      val2.append(class_0[sample][ar1[i]-1])
  print(v2)
  print(ar2)
  print(val2)
  for j in range(len(Subset_list)):
    if (ar2 == Subset_list[j]):
      f3 = list_mu[j]
      print(f3)
  
  min_cl0 = min(val2)
  db = 0
  for i in range(len(val2)):
    if (val2[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v3 = val2[temp]
    else :
      ar3.append(ar2[i])
      val3.append(class_0[sample][ar2[i]-1])
  print(v3)
  print(ar3)
  print(val3)
  for j in range(len(Subset_list)):
    if (ar3 == Subset_list[j]):
      f4 = list_mu[j]
      print(f4)

  min_cl0 = min(val3)
  db = 0
  for i in range(len(val3)):
    if (val3[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v4 = val3[temp]
    else :
      ar4.append(ar3[i])
      val4.append(class_0[sample][ar3[i]-1])
  print(v4)
  print(ar4)
  print(val4)
  for j in range(len(Subset_list)):
    if (ar4 == Subset_list[j]):
      f5 = list_mu[j]
      print(f5)
  v5 = val4[0]
  print(v5)
  fuzzy_estimate_cl0 = v1*1 + (v2-v1)*f2 + (v3-v2)*f3 + (v4-v3)*f4 + (v5-v4)*f5
  print("FUZZY ESTIMATE", fuzzy_estimate_cl0)
  fa_cl0.append(fuzzy_estimate_cl0)

# %%
fa_cl1 = []
for sample in range(len(class_0)):
  print(class_1[sample])
  min_cl0 = min(class_0[sample])
  ar1 = []
  val1 = []
  ar2 = []
  val2 = []
  ar3 = []
  val3 = []
  ar4 = []
  val4 = []
  db = 0
  for i in range(len(class_1[sample])):
    if (class_1[sample][i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db = db + 1
      v1 = class_1[sample][temp]
    else :
      ar1.append(i+1)
      val1.append(class_1[sample][i])
  print(v1)
  print(ar1)
  print(val1)
  for j in range(len(Subset_list)):
    if (ar1 == Subset_list[j]):
      f2 = list_mu[j]
      print(f2)

  min_cl0 = min(val1)
  db = 0
  for i in range(len(val1)):
    if (val1[i] == min_cl0 and db == 0):
      temp = i
      db =  db + 1
      print(temp+1)
      v2 = val1[temp]
    else :
      ar2.append(ar1[i])
      val2.append(class_1[sample][ar1[i]-1])
  print(v2)
  print(ar2)
  print(val2)
  for j in range(len(Subset_list)):
    if (ar2 == Subset_list[j]):
      f3 = list_mu[j]
      print(f3)
  
  min_cl0 = min(val2)
  db = 0
  for i in range(len(val2)):
    if (val2[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v3 = val2[temp]
    else :
      ar3.append(ar2[i])
      val3.append(class_1[sample][ar2[i]-1])
  print(v3)
  print(ar3)
  print(val3)
  for j in range(len(Subset_list)):
    if (ar3 == Subset_list[j]):
      f4 = list_mu[j]
      print(f4)

  min_cl0 = min(val3)
  db = 0
  for i in range(len(val3)):
    if (val3[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v4 = val3[temp]
    else :
      ar4.append(ar3[i])
      val4.append(class_1[sample][ar3[i]-1])
  print(v4)
  print(ar4)
  print(val4)
  for j in range(len(Subset_list)):
    if (ar4 == Subset_list[j]):
      f5 = list_mu[j]
      print(f5)
  v5 = val4[0]
  print(v5)
  fuzzy_estimate_cl1 = v1*1 + (v2-v1)*f2 + (v3-v2)*f3 + (v4-v3)*f4 + (v5-v4)*f5
  print("FUZZY ESTIMATE", fuzzy_estimate_cl1)
  fa_cl1.append(fuzzy_estimate_cl1)

# %%
fa_cl2 = []
for sample in range(len(class_0)):
  print(class_2[sample])
  min_cl0 = min(class_0[sample])
  ar1 = []
  val1 = []
  ar2 = []
  val2 = []
  ar3 = []
  val3 = []
  ar4 = []
  val4 = []
  db = 0
  for i in range(len(class_0[sample])):
    if (class_2[sample][i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db = db + 1
      v1 = class_2[sample][temp]
    else :
      ar1.append(i+1)
      val1.append(class_2[sample][i])
  print(v1)
  print(ar1)
  print(val1)
  for j in range(len(Subset_list)):
    if (ar1 == Subset_list[j]):
      f2 = list_mu[j]
      print(f2)

  min_cl0 = min(val1)
  db = 0
  for i in range(len(val1)):
    if (val1[i] == min_cl0 and db == 0):
      temp = i
      db =  db + 1
      print(temp+1)
      v2 = val1[temp]
    else :
      ar2.append(ar1[i])
      val2.append(class_2[sample][ar1[i]-1])
  print(v2)
  print(ar2)
  print(val2)
  for j in range(len(Subset_list)):
    if (ar2 == Subset_list[j]):
      f3 = list_mu[j]
      print(f3)
  
  min_cl0 = min(val2)
  db = 0
  for i in range(len(val2)):
    if (val2[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v3 = val2[temp]
    else :
      ar3.append(ar2[i])
      val3.append(class_2[sample][ar2[i]-1])
  print(v3)
  print(ar3)
  print(val3)
  for j in range(len(Subset_list)):
    if (ar3 == Subset_list[j]):
      f4 = list_mu[j]
      print(f4)

  min_cl0 = min(val3)
  db = 0
  for i in range(len(val3)):
    if (val3[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v4 = val3[temp]
    else :
      ar4.append(ar3[i])
      val4.append(class_2[sample][ar3[i]-1])
  print(v4)
  print(ar4)
  print(val4)
  for j in range(len(Subset_list)):
    if (ar4 == Subset_list[j]):
      f5 = list_mu[j]
      print(f5)
  v5 = val4[0]
  print(v5)
  fuzzy_estimate_cl2 = v1*1 + (v2-v1)*f2 + (v3-v2)*f3 + (v4-v3)*f4 + (v5-v4)*f5
  print("FUZZY ESTIMATE", fuzzy_estimate_cl2)
  fa_cl2.append(fuzzy_estimate_cl2)

# %%
fa_cl3 = []
for sample in range(len(class_0)):
  print(class_3[sample])
  min_cl0 = min(class_3[sample])
  ar1 = []
  val1 = []
  ar2 = []
  val2 = []
  ar3 = []
  val3 = []
  ar4 = []
  val4 = []
  db = 0
  for i in range(len(class_3[sample])):
    if (class_3[sample][i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db = db + 1
      v1 = class_0[sample][temp]
    else :
      ar1.append(i+1)
      val1.append(class_3[sample][i])
  print(v1)
  print(ar1)
  print(val1)
  for j in range(len(Subset_list)):
    if (ar1 == Subset_list[j]):
      f2 = list_mu[j]
      print(f2)

  min_cl0 = min(val1)
  db = 0
  for i in range(len(val1)):
    if (val1[i] == min_cl0 and db == 0):
      temp = i
      db =  db + 1
      print(temp+1)
      v2 = val1[temp]
    else :
      ar2.append(ar1[i])
      val2.append(class_0[sample][ar1[i]-1])
  print(v2)
  print(ar2)
  print(val2)
  for j in range(len(Subset_list)):
    if (ar2 == Subset_list[j]):
      f3 = list_mu[j]
      print(f3)
  
  min_cl0 = min(val2)
  db = 0
  for i in range(len(val2)):
    if (val2[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v3 = val2[temp]
    else :
      ar3.append(ar2[i])
      val3.append(class_3[sample][ar2[i]-1])
  print(v3)
  print(ar3)
  print(val3)
  for j in range(len(Subset_list)):
    if (ar3 == Subset_list[j]):
      f4 = list_mu[j]
      print(f4)

  min_cl0 = min(val3)
  db = 0
  for i in range(len(val3)):
    if (val3[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v4 = val3[temp]
    else :
      ar4.append(ar3[i])
      val4.append(class_3[sample][ar3[i]-1])
  print(v4)
  print(ar4)
  print(val4)
  for j in range(len(Subset_list)):
    if (ar4 == Subset_list[j]):
      f5 = list_mu[j]
      print(f5)
  v5 = val4[0]
  print(v5)
  fuzzy_estimate_cl3 = v1*1 + (v2-v1)*f2 + (v3-v2)*f3 + (v4-v3)*f4 + (v5-v4)*f5
  print("FUZZY ESTIMATE", fuzzy_estimate_cl3)
  fa_cl3.append(fuzzy_estimate_cl3)

# %%
result = []
for i in range(len(fa_cl0)):
  maximum = max(fa_cl0[i] , fa_cl1[i] , fa_cl2[i] , fa_cl3[i])
  if(maximum == fa_cl0[i]):
    result.append(0)
    print(0, "            ", maximum, "                    ", i , "  ", fa_cl0[i])
  if(maximum == fa_cl1[i]):
    result.append(1)
    print(1, "            ", maximum, "                    ", i , "  ", fa_cl0[i])
  if(maximum == fa_cl2[i]):
    result.append(2)
    print(2, "            ", maximum, "                    ", i,"  ", fa_cl0[i])
  if(maximum == fa_cl3[i]):
    result.append(3)
    print(3, "            ", maximum, "                    ", i)

# %%
df = pd.read_csv(r'/content/Binary_prediction_matrix.csv')
print (df)

# %%
predict = df[['vgg16', 'vgg19', 'xception', 'inceptionv3' , 'inceptionresnetv2']]
print(predict)
y_data = df['True Label']
print(y_data)

# %%
pred_mat = predict.values.tolist()
Y = y_data.values.tolist()

# %%
#Weight Calculation
sum = 0
w=[]
for i in range(5):
  w.append([0,0,0,0,0])
print(w)
val = [1, .998, 1, 1, .997]
for i in range(5):
  for j in range(5):
    if (i == j):
      w[i][j] = 0
    if (i != j):
      sum = 0
      for k in range(5):
        if  (k!=i and k!=j):
          sum = sum + val[k]
          print(val[k])
      avg = sum/3
      print(val)
      print(avg)
      print(i)
      print(j)
      w[i][j] = avg
      print("@@@@@@@@@@@@@@@@@@")

# %%
shapley_value_list = []
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  M = []
  for j in range(len(N)):
    if(i != N[j]):
      M.append(N[j])
  print(M)
  classifier_list =list(powerset(M))
  for k in range(len(classifier_list)):
    '''print(len(classifier_list[k]))'''
    st = str(classifier_list[k])
    classifier_subset = []
    for l in range(len(st)):
      if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
        classifier_subset.append(int(st[l]))
    '''print(classifier_subset)'''
    total = 0
    if(len(classifier_subset) == 1):
      a_1 = classifier_subset[0]
      X_1 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif = drv.information_mutual(X_i, X_1)
      marginal_info = m_info_class - w[i-1][a_1-1]*m_info_classif
      total = total + (marginal_info*6/120)
    if(len(classifier_subset) == 2):
      a_1 = classifier_subset[0]
      a_2 = classifier_subset[1]
      X_1 = []
      X_2 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      for asdf in range(len(pred_mat)):
        X_2.append(pred_mat[asdf][a_2-1])
      X_2 = np.asarray(X_2)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif_1 = drv.information_mutual(X_i, X_1)
      m_info_classif_2 = drv.information_mutual(X_i, X_2)
      m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2)/2
      marginal_info_2 = m_info_class - m_info_classif
      total = total + (marginal_info_2*4/120)
    if(len(classifier_subset) == 3):
      a_1 = classifier_subset[0]
      a_2 = classifier_subset[1]
      a_3 = classifier_subset[2]
      X_1 = []
      X_2 = []
      X_3 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      for asdf in range(len(pred_mat)):
        X_2.append(pred_mat[asdf][a_2-1])
      X_2 = np.asarray(X_2)
      for asdf in range(len(pred_mat)):
        X_3.append(pred_mat[asdf][a_3-1])
      X_3 = np.asarray(X_3)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif_1 = drv.information_mutual(X_i, X_1)
      m_info_classif_2 = drv.information_mutual(X_i, X_2)
      m_info_classif_3 = drv.information_mutual(X_i, X_3)
      m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][a_3-1]*m_info_classif_3)/3
      marginal_info_3 = m_info_class - m_info_classif
      total = total + (marginal_info_3*6/120)
    if(len(classifier_subset) == 4):
      a_1 = classifier_subset[0]
      a_2 = classifier_subset[1]
      a_3 = classifier_subset[2]
      a_4 = classifier_subset[3]
      X_1 = []
      X_2 = []
      X_3 = []
      X_4 = []
      for asdf in range(len(pred_mat)):
        X_1.append(pred_mat[asdf][a_1-1])
      X_1 = np.asarray(X_1)
      for asdf in range(len(pred_mat)):
        X_2.append(pred_mat[asdf][a_2-1])
      X_2 = np.asarray(X_2)
      for asdf in range(len(pred_mat)):
        X_3.append(pred_mat[asdf][a_3-1])
      X_3 = np.asarray(X_3)
      for asdf in range(len(pred_mat)):
        X_4.append(pred_mat[asdf][a_4-1])
      X_4 = np.asarray(X_4)
      m_info_class = drv.information_mutual(X_i, Y)
      m_info_classif_1 = drv.information_mutual(X_i, X_1)
      m_info_classif_2 = drv.information_mutual(X_i, X_2)
      m_info_classif_3 = drv.information_mutual(X_i, X_3)
      m_info_classif_4 = drv.information_mutual(X_i, X_4)
      m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][a_3-1]*m_info_classif_3 + w[i-1][a_4-1]*m_info_classif_4)/4
      marginal_info_4 =  m_info_class - m_info_classif
      total = total + marginal_info_4*24/120
  shapley_value = total 
  shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  for d in range(1,6,1):
    if(d == i):
      break
    X_d = []
    for asdf in range(len(pred_mat)):
      X_d.append(pred_mat[asdf][d-1])
    X_d = np.asarray(X_d)
    M = []
    for j in range(len(N)):
      if(i != N[j] and d != N[j]):
        M.append(N[j])
    print(M)
    classifier_list =list(powerset(M))
    for k in range(len(classifier_list)):
      '''print(len(classifier_list[k]))'''
      st = str(classifier_list[k])
      classifier_subset = []
      for l in range(len(st)):
        if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
          classifier_subset.append(int(st[l]))
      print(classifier_subset)
      total = 0
      if(len(classifier_subset) == 1):
        a_1 = classifier_subset[0]
        X_1 = []
        for asdf in range(len(pred_mat)):
          X_1.append(pred_mat[asdf][a_1-1])
        X_1 = np.asarray(X_1)
        m_info_class_1 = drv.information_mutual(X_i, Y)
        m_info_class_2 = drv.information_mutual(X_d, Y)
        m_info_classif_1 = drv.information_mutual(X_i, X_1)
        m_info_classif_2 = drv.information_mutual(X_i, X_d)
        m_info_classif_3 = drv.information_mutual(X_d, X_1)
        m_info_class = (m_info_class_1 + m_info_class_2)/2
        m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][d-1]*m_info_classif_2 + w[d-1][a_1-1]*m_info_classif_3)/3
        marginal_info_1 = m_info_class - m_info_classif
        total = total + (marginal_info_1*6/120)
      if(len(classifier_subset) == 2):
        a_1 = classifier_subset[0]
        a_2 = classifier_subset[1]
        X_1 = []
        X_2 = []
        for asdf in range(len(pred_mat)):
          X_1.append(pred_mat[asdf][a_1-1])
        X_1 = np.asarray(X_1)
        for asdf in range(len(pred_mat)):
          X_2.append(pred_mat[asdf][a_2-1])
        X_2 = np.asarray(X_2)
        m_info_class_1 = drv.information_mutual(X_i, Y)
        m_info_class_2 = drv.information_mutual(X_d, Y)
        m_info_classif_1 = drv.information_mutual(X_i, X_1)
        m_info_classif_2 = drv.information_mutual(X_i, X_2)
        m_info_classif_3 = drv.information_mutual(X_i, X_d)
        m_info_classif_4 = drv.information_mutual(X_d, X_2)
        m_info_classif_5 = drv.information_mutual(X_d, X_2)
        m_info_class = (m_info_class_1 + m_info_class_2)/2
        m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][d-1]*m_info_classif_3 + w[d-1][a_2-1]*m_info_classif_4 + w[d-1][a_2-1]*m_info_classif_5)/5
        marginal_info_2 = m_info_class - m_info_classif
        total = total + (marginal_info_2*4/120)
      if(len(classifier_subset) == 3):
        a_1 = classifier_subset[0]
        a_2 = classifier_subset[1]
        a_3 = classifier_subset[2]
        X_1 = []
        X_2 = []
        X_3 = []
        for asdf in range(len(pred_mat)):
          X_1.append(pred_mat[asdf][a_1-1])
        X_1 = np.asarray(X_1)
        for asdf in range(len(pred_mat)):
          X_2.append(pred_mat[asdf][a_2-1])
        X_2 = np.asarray(X_2)
        for asdf in range(len(pred_mat)):
          X_3.append(pred_mat[asdf][a_3-1])
        X_3 = np.asarray(X_3)
        m_info_class_1 = drv.information_mutual(X_i, Y)
        m_info_class_2 = drv.information_mutual(X_d, Y)
        m_info_classif_1 = drv.information_mutual(X_i, X_1)
        m_info_classif_2 = drv.information_mutual(X_i, X_2)
        m_info_classif_3 = drv.information_mutual(X_i, X_3)
        m_info_classif_4 = drv.information_mutual(X_d, X_1)
        m_info_classif_5 = drv.information_mutual(X_d, X_2)
        m_info_classif_6 = drv.information_mutual(X_d, X_3)
        m_info_classif_7 = drv.information_mutual(X_i, X_d)
        m_info_class = (m_info_class_1 + m_info_class_2)/2
        m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[i-1][a_3-1]*m_info_classif_3 + w[d-1][a_1-1]*m_info_classif_4 + w[d-1][a_2-1]*m_info_classif_5 + w[d-1][a_3-1]*m_info_classif_6 + w[i-1][d-1]*m_info_classif_7)/7
        marginal_info_3 = m_info_class - m_info_classif
        total = total + (marginal_info_3*6/120)
    shapley_value = total 
    shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  for d in range(1,6,1):
    if(d == i):
      break
    X_d = []
    for asdf in range(len(pred_mat)):
      X_d.append(pred_mat[asdf][d-1])
    X_d = np.asarray(X_d)
    for f in range(1,6,1):
      if( f == d or f==i):
        break
      X_f = []
      for asdf in range(len(pred_mat)):
        X_f.append(pred_mat[asdf][f-1])
      X_f = np.asarray(X_f)
      M = []
      for j in range(len(N)):
        if(i != N[j] and d != N[j] and f != N[j]):
          M.append(N[j])
      print(M)
      classifier_list =list(powerset(M))
      for k in range(len(classifier_list)):
        '''print(len(classifier_list[k]))'''
        st = str(classifier_list[k])
        classifier_subset = []
        for l in range(len(st)):
          if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
            classifier_subset.append(int(st[l]))
        print(classifier_subset)
        total = 0
        if(len(classifier_subset) == 1):
          a_1 = classifier_subset[0]
          X_1 = []
          for asdf in range(len(pred_mat)):
            X_1.append(pred_mat[asdf][a_1-1])
          X_1 = np.asarray(X_1)
          m_info_class_1 = drv.information_mutual(X_i, Y)
          m_info_class_2 = drv.information_mutual(X_d, Y)
          m_info_class_3 = drv.information_mutual(X_f, Y)
          m_info_classif_1 = drv.information_mutual(X_i, X_1)
          m_info_classif_2 = drv.information_mutual(X_i, X_d)
          m_info_classif_3 = drv.information_mutual(X_i, X_f)
          m_info_classif_4 = drv.information_mutual(X_d, X_f)
          m_info_classif_5 = drv.information_mutual(X_d, X_1)
          m_info_classif_6 = drv.information_mutual(X_f, X_1)
          m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3)/3
          m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][d-1]*m_info_classif_2 + w[i-1][f-1]*m_info_classif_3 + w[d-1][f-1]*m_info_classif_4 + w[d-1][a_1-1]*m_info_classif_5 + w[f-1][a_1-1]*m_info_classif_6)/6
          marginal_info_1 = m_info_class - m_info_classif
          total = total + (marginal_info_1*6/120)
        if(len(classifier_subset) == 2):
          a_1 = classifier_subset[0]
          a_2 = classifier_subset[1]
          X_1 = []
          X_2 = []
          for asdf in range(len(pred_mat)):
            X_1.append(pred_mat[asdf][a_1-1])
          X_1 = np.asarray(X_1)
          for asdf in range(len(pred_mat)):
            X_2.append(pred_mat[asdf][a_2-1])
          X_2 = np.asarray(X_2)
          m_info_class_1 = drv.information_mutual(X_i, Y)
          m_info_class_2 = drv.information_mutual(X_d, Y)
          m_info_class_3 = drv.information_mutual(X_f, Y)
          m_info_classif_1 = drv.information_mutual(X_i, X_1)
          m_info_classif_2 = drv.information_mutual(X_i, X_2)
          m_info_classif_3 = drv.information_mutual(X_d, X_1)
          m_info_classif_4 = drv.information_mutual(X_d, X_2)
          m_info_classif_5 = drv.information_mutual(X_f, X_1)
          m_info_classif_6 = drv.information_mutual(X_f, X_2)
          m_info_classif_7 = drv.information_mutual(X_i, X_d)
          m_info_classif_8 = drv.information_mutual(X_i, X_f)
          m_info_classif_9 = drv.information_mutual(X_d, X_f)
          m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3)/3
          m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][a_2-1]*m_info_classif_2 + w[d-1][a_1-1]*m_info_classif_3 + w[d-1][a_2-1]*m_info_classif_4 + w[f-1][a_2-1]*m_info_classif_5 + w[f-1][a_3-1]*m_info_classif_6 + w[i-1][d-1]*m_info_classif_7 + w[i-1][f-1]*m_info_classif_8 + w[d-1][f-1]*m_info_classif_9)/9
          marginal_info_2 = m_info_class - m_info_classif
          total = total + (marginal_info_2*4/120)
      shapley_value = total 
      shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
total = 0
for i in range(1, 6, 1):
  X_i = []
  for asdf in range(len(pred_mat)):
    X_i.append(pred_mat[asdf][i-1])
  X_i = np.asarray(X_i)
  for d in range(1,6,1):
    if(d == i):
      break
    X_d = []
    for asdf in range(len(pred_mat)):
      X_d.append(pred_mat[asdf][d-1])
    X_d = np.asarray(X_d)
    for f in range(1,6,1):
      if( f == d or f==i):
        break
      X_f = []
      for asdf in range(len(pred_mat)):
        X_f.append(pred_mat[asdf][f-1])
      X_f = np.asarray(X_f)
      for r in range(1,6,1):
        if( r == d or r==i or r == f):
          break
        X_r = []
        for asdf in range(len(pred_mat)):
          X_r.append(pred_mat[asdf][r-1])
        X_r = np.asarray(X_r)
        M = []
        for j in range(len(N)):
          if(i != N[j] and d != N[j] and f != N[j] and r != N[j]):
            M.append(N[j])
        print(M)
        classifier_list =list(powerset(M))
        for k in range(len(classifier_list)):
          '''print(len(classifier_list[k]))'''
          st = str(classifier_list[k])
          classifier_subset = []
          for l in range(len(st)):
            if(st[l] == "1" or st[l] == "2" or st[l] == "3" or st[l] == "4" or st[l] == "5"):
              classifier_subset.append(int(st[l]))
          print(classifier_subset)
          total = 0
          if(len(classifier_subset) == 1):
            a_1 = classifier_subset[0]
            X_1 = []
            for asdf in range(len(pred_mat)):
              X_1.append(pred_mat[asdf][a_1-1])
            X_1 = np.asarray(X_1)
            m_info_class_1 = drv.information_mutual(X_i, Y)
            m_info_class_2 = drv.information_mutual(X_d, Y)
            m_info_class_3 = drv.information_mutual(X_f, Y)
            m_info_class_4 = drv.information_mutual(X_r, Y)
            m_info_classif_1 = drv.information_mutual(X_i, X_1)
            m_info_classif_2 = drv.information_mutual(X_i, X_d)
            m_info_classif_3 = drv.information_mutual(X_i, X_r)
            m_info_classif_4 = drv.information_mutual(X_r, X_d)
            m_info_classif_5 = drv.information_mutual(X_r, X_f)
            m_info_classif_6 = drv.information_mutual(X_i, X_f)
            m_info_classif_7 = drv.information_mutual(X_d, X_f)
            m_info_classif_8 = drv.information_mutual(X_d, X_1)
            m_info_classif_9 = drv.information_mutual(X_f, X_1)
            m_info_classif_10 = drv.information_mutual(X_r, X_1)
            m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3 + m_info_class_4)/4
            m_info_classif = (w[i-1][a_1-1]*m_info_classif_1 + w[i-1][d-1]*m_info_classif_2 + w[i-1][r-1]*m_info_classif_3 + w[r-1][d-1]*m_info_classif_4 + w[r-1][f-1]*m_info_classif_5 + w[i-1][f-1]*m_info_classif_6 + w[d-1][f-1]*m_info_classif_7 + w[d-1][a_1-1]*m_info_classif_8 + w[f-1][a_1-1]*m_info_classif_9 + w[r-1][a_1-1]*m_info_classif_10)/10
            marginal_info_1 = m_info_class - m_info_classif
            total = total + (marginal_info_1*6/120)
        shapley_value = total 
        shapley_value_list.append(shapley_value)

# %%
X_i = []
X_d = []
X_f = []
X_r = []
X_p = []
for asdf in range(len(pred_mat)):
  X_i.append(pred_mat[asdf][0])
X_i = np.asarray(X_i)
for asdf in range(len(pred_mat)):
  X_d.append(pred_mat[asdf][1])
X_d = np.asarray(X_d)
for asdf in range(len(pred_mat)):
  X_f.append(pred_mat[asdf][2])
X_f = np.asarray(X_f)
for asdf in range(len(pred_mat)):
  X_r.append(pred_mat[asdf][3])
X_r = np.asarray(X_r)
for asdf in range(len(pred_mat)):
  X_p.append(pred_mat[asdf][4])
X_p = np.asarray(X_p)
m_info_class_1 = drv.information_mutual(X_i, Y)
m_info_class_2 = drv.information_mutual(X_d, Y)
m_info_class_3 = drv.information_mutual(X_f, Y)
m_info_class_4 = drv.information_mutual(X_r, Y)
m_info_class_5 = drv.information_mutual(X_p, Y)
m_info_classif_1 = drv.information_mutual(X_i, X_d)
m_info_classif_2 = drv.information_mutual(X_i, X_f)
m_info_classif_3 = drv.information_mutual(X_i, X_r)
m_info_classif_4 = drv.information_mutual(X_i, X_p)
m_info_classif_5 = drv.information_mutual(X_d, X_f)
m_info_classif_6 = drv.information_mutual(X_d, X_r)
m_info_classif_7 = drv.information_mutual(X_d, X_p)
m_info_classif_8 = drv.information_mutual(X_f, X_r)
m_info_classif_9 = drv.information_mutual(X_f, X_p)
m_info_classif_10 = drv.information_mutual(X_r, X_p)
m_info_class = (m_info_class_1 + m_info_class_2 + m_info_class_3 + m_info_class_4 + m_info_class_5)/5
m_info_classif = (w[0][1]*m_info_classif_1 + w[0][2]*m_info_classif_2 + w[0][3]*m_info_classif_3 + w[0][4]*m_info_classif_4 + w[1][2]*m_info_classif_5 + w[1][3]*m_info_classif_6 + w[1][4]*m_info_classif_7 + w[2][3]*m_info_classif_8 + w[2][4]*m_info_classif_9 + w[3][4]*m_info_classif_10)/10
marginal_info_1 = m_info_class - m_info_classif
total = total + (marginal_info_1*6/120)
shapley_value = total 
shapley_value_list.append(shapley_value)

# %%
N = [1,2,3,4,5]
Subset_list = []
total = 0
for i in range(1, 6, 1):
  K =[]
  K.append(i)
  Subset_list.append(K)
print(Subset_list)
for i in range(1, 6, 1):
  for d in range(1,6,1):
    K = []
    if(d == i):
      break
    K.append(d)
    K.append(i)
    Subset_list.append(K)
print(Subset_list)
for i in range(1, 6, 1):
  for d in range(1,6,1):
    if(d == i):
      break
    for f in range(1,6,1):
      K = []
      if( f == d or f==i):
        break
      K.append(f)
      K.append(d)
      K.append(i)
      Subset_list.append(K)
print(Subset_list)
for i in range(1, 6, 1):
  for d in range(1,6,1):
    if(d == i):
      break
    for f in range(1,6,1):
      if( f == d or f==i):
        break
      for r in range(1,6,1):
        K = []
        if( r == d or r==i or r == f):
          break
        K.append(r)
        K.append(f)
        K.append(d)
        K.append(i)
        Subset_list.append(K)
print(Subset_list)
K = []
K.append(1)
K.append(2)
K.append(3)
K.append(4)
K.append(5)
Subset_list.append(K)
print(Subset_list)

# %%
list_mu = []
list_mu.append(shapley_value_list[0])
list_mu.append(shapley_value_list[1])
list_mu.append(shapley_value_list[2])
list_mu.append(shapley_value_list[3])
list_mu.append(shapley_value_list[4])
for i in range(5, len(Subset_list)):
  K = Subset_list[i]
  if (len(K) == 2):
    shap_of_2 = shapley_value_list[i]
    m1 = K[0]
    m2 = K[1]
    temp1 = shapley_value_list[m1-1]
    temp2 = shapley_value_list[m2-1]
    if (temp1>temp2):
      mu_m2 = temp1
      mu_m1 = temp2
    else:
      mu_m2 = temp2
      mu_m1 = temp1
    mu_additive = mu_m1 + mu_m2
    if (mu_m2 == mu_m1):
      print(K)
      if (shap_of_2 < mu_m2 and shap_of_2 > 0):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2)
        mu_of_2 = (r1*mu_additive + r2*mu_m2)/(r1 + r2)
        print(mu_of_2)
        list_mu.append(mu_of_2)
      if(shap_of_2 >= mu_m2):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2)
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
        print(mu_of_2)
        list_mu.append(mu_of_2)
    if (mu_m2 >= 0 and mu_m1 >= 0 and mu_m2 != mu_m1):
      ratio = (mu_m2 - mu_m1)/mu_m2
      fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
      if (shap_of_2 >= mu_m2):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2 - mu_m1)
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
      if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2 - mu_m1)
        mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
      if (shap_of_2 < mu_m1 and shap_of_2 > 0):
        r2 = abs(shap_of_2 - mu_m2)
        r1 = abs(shap_of_2 - mu_m1)
        mu_of_2 = (r2*fixed_pt - r1*mu_additive)/(r2 - r1)
      if (shap_of_2 <= 0):
        mu_of_2 = mu_m2
      list_mu.append(mu_of_2)
      print(K)
      print(mu_of_2)
  if(len(K) == 3):
    shap_of_2 = shapley_value_list[i]
    maximum = 0
    ARR = []
    for t in range(0,len(K)):
      for g in range(0,len(K)):
        check = []
        if (K[t] > K[g]):
          check.append(K[g])
          check.append(K[t])
          for r in range(5 , 15):
            if (check == Subset_list[r]):
              sh = list_mu[r]
              if (sh> maximum):
                maximum = sh
                ARR = check
                for ss in range(0,3):
                  if (ss!= t and ss != g):
                    left = K[ss]
                    break
    temp = list_mu[left-1]
    if (maximum > temp): 
      mu_m2 = maximum
      mu_m1 = temp
    else:
      mu_m2 = temp
      mu_m1 = maximum
    mu_additive = mu_m1 + mu_m2
    if (mu_m2 >= 0 and mu_m1 >= 0):
      ratio = (mu_m2 - mu_m1)/mu_m2
      fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
      if (shap_of_2 >= mu_m2):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
      if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
      if (shap_of_2 < mu_m1 and shap_of_2 > 0):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r2*fixed_pt - r1*mu_additive )/(r2 - r1)
      if (shap_of_2 <= 0):
        mu_of_2 = mu_m2
      list_mu.append(mu_of_2)
      print(K)
      print(mu_of_2)
  if (len(K) == 4):
      shap_of_2 = shapley_value_list[i]
      maximum = 0
      ARR = []
      for t in range(0,len(K)):
            for g in range(0,len(K)):
              for h in range(0,len(K)):
                check = []
                if (t > g and g > h ):
                  check.append(K[t])
                  check.append(K[g])
                  check.append(K[h])
                  check.sort()
                  print(check)
                  for r in range(15 , 25):
                    if (check == Subset_list[r]):
                      sh = list_mu[r]
                      if (sh> maximum):
                        maximum = sh
                        ARR = check
                        for ss in range(0,3):
                          if (ss!= t and ss != g):
                            left = K[ss]
                            break
      temp = list_mu[left-1]
      if (maximum > temp): 
        mu_m2 = maximum
        mu_m1 = temp
      else:
        mu_m2 = temp
        mu_m1 = maximum
      mu_additive = mu_m1 + mu_m2
      if (mu_m2 >= 0 and mu_m1 >= 0):
        ratio = (mu_m2 - mu_m1)/mu_m2
        fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
        if (shap_of_2 >= mu_m2):
          r2 = shap_of_2 - mu_m2
          r1 = shap_of_2 - mu_m1
          mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
        if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
          r2 = shap_of_2 - mu_m2
          r1 = shap_of_2 - mu_m1
          mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
        if (shap_of_2 < mu_m1 and shap_of_2 > 0):
          r2 = shap_of_2 - mu_m2
          r1 = shap_of_2 - mu_m1
          mu_of_2 = (r2*fixed_pt - r1*mu_additive )/(r2 - r1)
        if (shap_of_2 <= 0):
          mu_of_2 = mu_m2
        list_mu.append(mu_of_2)
  if (len(K) == 5):
    shap_of_2 = shapley_value_list[i]
    maximum = 0
    ARR = []
    for t in range(0,len(K)):
      for g in range(0,len(K)):
        for h in range(0,len(K)):
          for ee in range(0, len(K)):
            check = []
            if (t > g and g > h and h > ee ):
              check.append(K[t])
              check.append(K[g])
              check.append(K[h])
              check.append(K[ee])
              check.sort()
              print(check)
              for r in range(25 , 30):
                    if (check == Subset_list[r]):
                      sh = list_mu[r]
                      if (sh> maximum):
                        maximum = sh
                        ARR = check
                        for ss in range(0,3):
                          if (ss!= t and ss != g):
                            left = K[ss]
                            break
    temp = list_mu[left-1]
    if (maximum > temp): 
      mu_m2 = maximum
      mu_m1 = temp
    else:
      mu_m2 = temp
      mu_m1 = maximum
    mu_additive = mu_m1 + mu_m2
    if (mu_m2 >= 0 and mu_m1 >= 0):
      ratio = (mu_m2 - mu_m1)/mu_m2
      fixed_pt = mu_additive - (mu_additive - mu_m2)*ratio
      if (shap_of_2 >= mu_m2):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive - r2*fixed_pt)/(r1 - r2)
      if (shap_of_2<mu_m2 and shap_of_2>= mu_m1):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r1*mu_additive + r2*fixed_pt)/(r1 + r2)
      if (shap_of_2 < mu_m1 and shap_of_2 > 0):
        r2 = shap_of_2 - mu_m2
        r1 = shap_of_2 - mu_m1
        mu_of_2 = (r2*fixed_pt - r1*mu_additive )/(r2 - r1)
      if (shap_of_2 <= 0):
        mu_of_2 = mu_m2  
      list_mu.append(mu_of_2)

# %%
measure_max = max(list_mu)
print(measure_max)

# %%
for k in range(len(list_mu)):
  list_mu[k] = list_mu[k]/measure_max

# %%
for k in range(len(list_mu)):
  print(k)
  print(Subset_list[k])
  print(list_mu[k])

# %%
df_1 = pd.read_csv(r'/content/Binary_confidence_matrix.csv')
print (df_1)

# %%
class_0 = df_1[['vgg16_class0', 'vgg19_class0', 'xception_class0', 'inception_class0' , 'incepresnet_class0']]
print(class_0)
class_1 = df_1[['vgg16_class1', 'vgg19_class1', 'xception_class1', 'inception_class1' , 'incepresnet_class1']]
print(class_1)

# %%
class_0 = class_0.values.tolist()
class_1 = class_1.values.tolist()

# %%
fa_cl0 = []
for sample in range(len(class_0)):
  print(class_0[sample])
  min_cl0 = min(class_0[sample])
  ar1 = []
  val1 = []
  ar2 = []
  val2 = []
  ar3 = []
  val3 = []
  ar4 = []
  val4 = []
  db = 0
  for i in range(len(class_0[sample])):
    if (class_0[sample][i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db = db + 1
      v1 = class_0[sample][temp]
    else :
      ar1.append(i+1)
      val1.append(class_0[sample][i])
  print(v1)
  print(ar1)
  print(val1)
  for j in range(len(Subset_list)):
    if (ar1 == Subset_list[j]):
      f2 = list_mu[j]
      print(f2)

  min_cl0 = min(val1)
  db = 0
  for i in range(len(val1)):
    if (val1[i] == min_cl0 and db == 0):
      temp = i
      db =  db + 1
      print(temp+1)
      v2 = val1[temp]
    else :
      ar2.append(ar1[i])
      val2.append(class_0[sample][ar1[i]-1])
  print(v2)
  print(ar2)
  print(val2)
  for j in range(len(Subset_list)):
    if (ar2 == Subset_list[j]):
      f3 = list_mu[j]
      print(f3)
  
  min_cl0 = min(val2)
  db = 0
  for i in range(len(val2)):
    if (val2[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v3 = val2[temp]
    else :
      ar3.append(ar2[i])
      val3.append(class_0[sample][ar2[i]-1])
  print(v3)
  print(ar3)
  print(val3)
  for j in range(len(Subset_list)):
    if (ar3 == Subset_list[j]):
      f4 = list_mu[j]
      print(f4)

  min_cl0 = min(val3)
  db = 0
  for i in range(len(val3)):
    if (val3[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v4 = val3[temp]
    else :
      ar4.append(ar3[i])
      val4.append(class_0[sample][ar3[i]-1])
  print(v4)
  print(ar4)
  print(val4)
  for j in range(len(Subset_list)):
    if (ar4 == Subset_list[j]):
      f5 = list_mu[j]
      print(f5)
  v5 = val4[0]
  print(v5)
  fuzzy_estimate_cl0 = v1*1 + (v2-v1)*f2 + (v3-v2)*f3 + (v4-v3)*f4 + (v5-v4)*f5
  print("FUZZY ESTIMATE", fuzzy_estimate_cl0)
  fa_cl0.append(fuzzy_estimate_cl0)

# %%
fa_cl1 = []
for sample in range(len(class_0)):
  print(class_1[sample])
  min_cl0 = min(class_0[sample])
  ar1 = []
  val1 = []
  ar2 = []
  val2 = []
  ar3 = []
  val3 = []
  ar4 = []
  val4 = []
  db = 0
  for i in range(len(class_1[sample])):
    if (class_1[sample][i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db = db + 1
      v1 = class_1[sample][temp]
    else :
      ar1.append(i+1)
      val1.append(class_1[sample][i])
  print(v1)
  print(ar1)
  print(val1)
  for j in range(len(Subset_list)):
    if (ar1 == Subset_list[j]):
      f2 = list_mu[j]
      print(f2)

  min_cl0 = min(val1)
  db = 0
  for i in range(len(val1)):
    if (val1[i] == min_cl0 and db == 0):
      temp = i
      db =  db + 1
      print(temp+1)
      v2 = val1[temp]
    else :
      ar2.append(ar1[i])
      val2.append(class_1[sample][ar1[i]-1])
  print(v2)
  print(ar2)
  print(val2)
  for j in range(len(Subset_list)):
    if (ar2 == Subset_list[j]):
      f3 = list_mu[j]
      print(f3)
  
  min_cl0 = min(val2)
  db = 0
  for i in range(len(val2)):
    if (val2[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v3 = val2[temp]
    else :
      ar3.append(ar2[i])
      val3.append(class_1[sample][ar2[i]-1])
  print(v3)
  print(ar3)
  print(val3)
  for j in range(len(Subset_list)):
    if (ar3 == Subset_list[j]):
      f4 = list_mu[j]
      print(f4)

  min_cl0 = min(val3)
  db = 0
  for i in range(len(val3)):
    if (val3[i] == min_cl0 and db == 0):
      temp = i
      print(temp+1)
      db =  db + 1
      v4 = val3[temp]
    else :
      ar4.append(ar3[i])
      val4.append(class_1[sample][ar3[i]-1])
  print(v4)
  print(ar4)
  print(val4)
  for j in range(len(Subset_list)):
    if (ar4 == Subset_list[j]):
      f5 = list_mu[j]
      print(f5)
  v5 = val4[0]
  print(v5)
  fuzzy_estimate_cl1 = v1*1 + (v2-v1)*f2 + (v3-v2)*f3 + (v4-v3)*f4 + (v5-v4)*f5
  print("FUZZY ESTIMATE", fuzzy_estimate_cl1)
  fa_cl1.append(fuzzy_estimate_cl1)

# %%
result = []
for i in range(len(fa_cl0)):
  maximum = max(fa_cl0[i] , fa_cl1[i])
  if(maximum == fa_cl0[i]):
    result.append(0)
    print(0, "            ", maximum, "                    ", i , "  ", fa_cl0[i])
  if(maximum == fa_cl1[i]):
    result.append(1)
    print(1, "            ", maximum, "                    ", i , "  ", fa_cl0[i])
